# %%
import requests # use to retrieve data from API
import math
import pandas as pd
import datetime as datetime
#import os

# %%
pd.read_csv("C:/Users/yangs/Documents/Coding/rs3-ml/src/ge-prices-2024-07-28.csv")
# Out:
#          index     id  price   volume      timestamp        date  weekday  \
# 0          180  52937   1653      NaN  1646092800000  2022-03-01        1
# 1          181  52937   1736      NaN  1646179200000  2022-03-02        1
# 2          182  52937   1823      NaN  1646265600000  2022-03-03        1
# 3          183  52937   1915      NaN  1646352000000  2022-03-04        1
# 4          184  52937   2011      NaN  1646438400000  2022-03-05        0
# ...        ...    ...    ...      ...            ...         ...      ...
# 550555  723468  43983    483  16747.0  1721748680000  2024-07-23        1
# 550556  723469  43983    483  17274.0  1721804620000  2024-07-24        1
# 550557  723470  43983    480  15194.0  1721928652000  2024-07-25        1
# 550558  723471  43983    480  11417.0  1721993510000  2024-07-26        1
# 550559  723472  43983    480  21458.0  1722066488000  2024-07-27        0
#
#                   name  diff_1_day  diff_7_day  diff_14_day  diff_30_day  \
# ...
